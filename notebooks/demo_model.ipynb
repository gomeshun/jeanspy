# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
import model_numpyro
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import jax.numpy as jnp
#       2 import matplotlib.pyplot as plt
# ----> 3 import model_numpyro
#
# File ~/workspace/dev_jeanspy/jeanspy/model_numpyro.py:16
#      14 import jax.numpy as jnp
#      15 import jax.scipy.special as jsp
# ---> 16 from jeanspy.hyp2f1_jax import hyp2f1_1b_3half
#      18 # Optional logger (used by callers/tests; kept lightweight)
#      19 import logging
#
# ModuleNotFoundError: No module named 'jeanspy'

# %%
import arviz
arviz.__version__
# Out:
# '1.0.0'
